# %% [markdown]
# # Train YOLOv8 Object Detection

# %% [markdown]
# ## Installing package..

# %%
# Install ClearML
# !pip install clearml

# Install YOLOv8
# !pip install ultralytics

# !pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.4 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.2/584.2 kB 40.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 25.7 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Import Stuff

# %%
import clearml
from ultralytics import YOLO

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# e:\Bekerja\Lamaran\eFishery\Project_3\program\train

# %% [markdown]
# ## ClearML

# %%
# Login ClearML
clearml.browser_login()

task = clearml.Task.init(
    project_name='Vibrio',    # project name of at least 3 characters
    task_name='Vibrio_Training_YOLOv8_Small', # task name of at least 3 characters
    task_type="training",
    tags=["YOLOv8", "Small"]  
)
# Out:
# ClearML Task: overwriting (reusing) task id=555418731f1d469690230e67780772a9
# 2023-05-12 13:23:59,976 - clearml.Repository Detection - WARNING - Could not read Jupyter Notebook: No module named 'nbconvert'
# 2023-05-12 13:24:00,007 - clearml.Task - INFO - Storing jupyter notebook directly as code
# ClearML results page: https://app.clear.ml/projects/56e079f681db4cb89d774563d44c8c18/experiments/555418731f1d469690230e67780772a9/output/log

# %% [markdown]
# ## Import Dataset with Roboflow

# %%
# %mkdir {HOME}/datasets
# %cd {HOME}/datasets


from roboflow import Roboflow
rf = Roboflow(api_key="74Pb2GaCvTDY3KSnoxeK")
project = rf.workspace("wiranda-aditiya-znixh").project("vibrio-dt175")
dataset = project.version(3).download("yolov8")
# Out:
# The syntax of the command is incorrect.
# [WinError 2] The system cannot find the file specified: 'e:\\Bekerja\\Lamaran\\eFishery\\Project_3\\program\\train/datasets'
# e:\Bekerja\Lamaran\eFishery\Project_3\program\train
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.98, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to vibrio-3 in yolov8:: 100%|██████████| 95/95 [00:00<00:00, 2063.48it/s]

# %% [markdown]
# ## Train with YOLOv8

# %%
#@title Select an Image Classification model
# !mkdir {HOME}/model_pretrained
# %cd {HOME}/model_pretrained
model_name = "YOLOv8-Nano" #@param ["YOLOv8-Nano", "YOLOv8-Small", "YOLOv8-Medium", "YOLOv8-Large", "YOLOv8-Xtreme"]

model_handle = {
    "YOLOv8-Nano" : YOLO('yolov8n.pt'),
    "YOLOv8-Small" : YOLO("yolov8s.pt"),
    "YOLOv8-Medium" : YOLO("yolov8m.pt"),
    "YOLOv8-Large" : YOLO("yolov8l.pt"),
    "YOLOv8-Xtreme" : YOLO("yolov8x.pt")
}

model_handle = model_handle[model_name]

print(f"Selected model: {model_name} : {model_handle}")
# Out:
# ...
# /content/model_pretrained
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 258MB/s]
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 210MB/s]
# ...
# 100%|██████████| 49.7M/49.7M [00:02<00:00, 20.0MB/s]
# ...
# 100%|██████████| 83.7M/83.7M [00:04<00:00, 19.3MB/s]
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 330MB/s]
# Selected model: YOLOv8-Nano : <ultralytics.yolo.engine.model.YOLO object at 0x7ff8a05fa920>

# %%
model_handle = YOLO("yolov8s.pt")
# Out:
# 2023-05-12 13:24:08,937 - clearml.model - INFO - Selected model id: 612950f26b2d4ef3b008790b72536ba1

# %%
import os
# Use the model
results = model_handle.train(
    data=os.path.join(dataset.location, "data.yaml"),
    batch=1,
    epochs=5,
    workers=0,
    patience=100,
    imgsz=640)  # train the model
# Out:
# Ultralytics YOLOv8.0.98  Python-3.11.3 torch-2.0.1 CPU
# ...

# %%
import torch

torch.cuda.is_available()
# Out:
# True
